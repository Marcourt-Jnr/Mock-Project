# %%
import pandas as pd
import plotly.express as px

pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)

# %%
data= pd.read_csv('./data/HRDataset_v14.csv')

# %%
data
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
#setting EmpID as index
data.set_index('EmpID')
# Out:
#                   Employee_Name  MarriedID  MaritalStatusID  GenderID  \
# EmpID
# 10026       Adinolfi, Wilson  K          0                0         1
# 10084  Ait Sidi, Karthikeyan             1                1         1
# 10196         Akinkuolie, Sarah          1                1         0
# 10088              Alagbe,Trina          1                1         0
# 10069          Anderson, Carol           0                2         0
# ...                         ...        ...              ...       ...
# 10135            Woodson, Jason          0                0         1
# 10301        Ybarra, Catherine           0                0         0
# 10010          Zamora, Jennifer          0                0         0
# 10043               Zhou, Julia          0                0         0
# 10271             Zima, Colleen          0                4         0
#
#        EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  \
# EmpID
# ...

# %%
#checking data types 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
data['DateofHire'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 311 entries, 0 to 310
# Series name: DateofHire
# Non-Null Count  Dtype
# --------------  -----
# 311 non-null    object
# dtypes: object(1)
# memory usage: 2.6+ KB

# %%
data['DateofTermination'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 311 entries, 0 to 310
# Series name: DateofTermination
# Non-Null Count  Dtype
# --------------  -----
# 104 non-null    object
# dtypes: object(1)
# memory usage: 2.6+ KB

# %%
#converting to datetime type
data['DateofHire'] = pd.to_datetime(data['DateofHire'])
data['DateofTermination'] = pd.to_datetime(data['DateofTermination'])

# %%
#checking the null
data.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
#highest paid employee
highest_paid = data.pivot_table(
    index = 'Employee_Name',
    values = 'Salary',
    aggfunc= 'max'
).sort_values(by = 'Salary',ascending=False)
highest_paid.head(10)
# Out:
#                   Salary
# Employee_Name
# King, Janet       250000
# Zamora, Jennifer  220450
# Houlihan, Debra   180000
# Foss, Jason       178000
# Corleone, Vito    170500
# Monroe, Peter     157000
# Roper, Katie      150290
# Ruiz, Ricardo     148999
# Roup,Simon        140920
# Dougall, Eric     138888

# %%
#creating a variable for obtaining PIP values
data_for_pip= data[['Employee_Name','PerformanceScore']]

# %%
data_for_pip
# Out:
#                 Employee_Name PerformanceScore
# 0         Adinolfi, Wilson  K          Exceeds
# 1    Ait Sidi, Karthikeyan         Fully Meets
# 2           Akinkuolie, Sarah      Fully Meets
# 3                Alagbe,Trina      Fully Meets
# 4            Anderson, Carol       Fully Meets
# ..                        ...              ...
# 306            Woodson, Jason      Fully Meets
# 307        Ybarra, Catherine               PIP
# 308          Zamora, Jennifer          Exceeds
# 309               Zhou, Julia      Fully Meets
# 310             Zima, Colleen      Fully Meets
#
# [311 rows x 2 columns]

# %%
#getting employees who requires PIP
data_for_pip[(data_for_pip['PerformanceScore']=='PIP')]
# Out:
#            Employee_Name PerformanceScore
# 67         Delarge, Alex              PIP
# 69       Desimone, Carl               PIP
# 72     Dietrich, Jenna                PIP
# 83        Erilus, Angela              PIP
# 90   Fernandes, Nilson                PIP
# 91            Fett, Boba              PIP
# 95         Forrest, Alex              PIP
# 112       Gonzalez, Juan              PIP
# 188          Miller, Ned              PIP
# 205         O'hare, Lynn              PIP
# 263     Sparks, Taylor                PIP
# 267   Stansfield, Norman              PIP
# 307   Ybarra, Catherine               PIP

# %%
#data for absences
data_for_absences = data[['Employee_Name','Absences']]
data_for_absences
# Out:
#                 Employee_Name  Absences
# 0         Adinolfi, Wilson  K         1
# 1    Ait Sidi, Karthikeyan           17
# 2           Akinkuolie, Sarah         3
# 3                Alagbe,Trina        15
# 4            Anderson, Carol          2
# ..                        ...       ...
# 306            Woodson, Jason        13
# 307        Ybarra, Catherine          4
# 308          Zamora, Jennifer        16
# 309               Zhou, Julia        11
# 310             Zima, Colleen         2
#
# [311 rows x 2 columns]

# %%
data_for_absences2 = data_for_absences.groupby('Absences').count()

data_for_absences2
# Out:
#           Employee_Name
# Absences
# 1                    14
# 2                    21
# 3                    16
# 4                    23
# 5                    12
# 6                    16
# 7                    21
# 8                    11
# 9                    14
# 10                   10
# 11                   15
# 12                    8
# 13                   17
# 14                   17
# 15                   20
# 16                   23
# 17                   15
# 18                    8
# 19                   16
# 20                   14

# %%
#employees that are married and employees that are single
married_employees= data['MaritalDesc'].value_counts()['Married']
single_emloyees = data['MaritalDesc'].value_counts()['Single']

print(f'{married_employees} employees are Married and {single_emloyees} employees are still single')
# Out:
# 124 employees are Married and 137 employees are still single

# %%
data = data.pivot_table(
    index = 'Absences',
    values = 'Sales',
    aggfunc='sum'
).sort_values(by='Sales',ascending=True)
hourly_sales
